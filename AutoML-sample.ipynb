# %% [markdown]
# # Load Dataset

# %%
#load dataset

# %%
# set X,y
#### code here
X
y

#### code here

# %%
# %%time
# import model to use
import model
####################################
# Use find to find best of best
####################################

model.find(X,y)
