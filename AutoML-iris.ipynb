# %% [markdown]
# # Load Database

# %%
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target

# %% [markdown]
# # simple use
# ---

# %%
# %%time
import model
model.find(X,y)
# Out:
#                 data  type normal
#                 dimension reduction  type normal
#                 i 0
#
#
#         model : KNeighborsClassifier
#
# normal data with normal dimension reduction - KNeighborsClassifier: training accuracy=86.67%, test accuracy=76.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  5  6]]
#         model : SVC
#
# normal data with normal dimension reduction - SVC: training accuracy=78.33%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : GaussianProcessClassifier
#
# normal data with normal dimension reduction - GaussianProcessClassifier: training accuracy=81.67%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  1 10]]
#         model : ExtraTreesClassifier
#
# normal data with normal dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=70.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  6  5]]
#         model : GaussianNB
#
# normal data with normal dimension reduction - GaussianNB: training accuracy=77.50%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#     ##############################
#     #### Find best parameter ####
#     ##############################
#
#     MAX SCORE: 0.9416666666666667
#
#     Preprocessing type: normal
#
#     Dimension reduction type: normal
#
#     Model type:  ExtraTreesClassifier
#     *** normal mean normal data without any change
#
# CPU times: user 2.72 s, sys: 3.56 s, total: 6.28 s
# Wall time: 1.67 s

# %% [markdown]
# ---
# # test size 20%
# #  without normize
# #  without Dimension reduction
# # all models
# ---

# %%
# %%time
######
model.find(X, y, 0.2, 0, 0, 1)
# Out:
#                 data  type normal
#                 dimension reduction  type normal
#                 i 0
#
#
#         model : KNeighborsClassifier
#
# normal data with normal dimension reduction - KNeighborsClassifier: training accuracy=86.67%, test accuracy=76.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  5  6]]
#         model : SVC
#
# normal data with normal dimension reduction - SVC: training accuracy=78.33%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : GaussianProcessClassifier
#
# normal data with normal dimension reduction - GaussianProcessClassifier: training accuracy=81.67%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  1 10]]
#         model : ExtraTreesClassifier
#
# normal data with normal dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=70.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  6  5]]
#         model : GaussianNB
#
# normal data with normal dimension reduction - GaussianNB: training accuracy=77.50%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : SVC_2
#
# normal data with normal dimension reduction - SVC_2: training accuracy=79.17%, test accuracy=93.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  0 11]]
#         model : DecisionTreeClassifier
#
# normal data with normal dimension reduction - DecisionTreeClassifier: training accuracy=94.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[9 1 0]
#  [0 4 5]
#  [0 5 6]]
#         model : RandomForestClassifier
#
# normal data with normal dimension reduction - RandomForestClassifier: training accuracy=94.17%, test accuracy=80.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  4  7]]
#         model : MLPClassifier
#
# normal data with normal dimension reduction - MLPClassifier: training accuracy=79.17%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  1 10]]
#         model : AdaBoostClassifier
#
# normal data with normal dimension reduction - AdaBoostClassifier: training accuracy=74.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  4  5]
#  [ 0  6  5]]
#         model : QuadraticDiscriminantAnalysis
#
# normal data with normal dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=76.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#     ##############################
#     #### Find best parameter ####
#     ##############################
#
#     MAX SCORE: 0.9416666666666667
#
#     Preprocessing type: normal
#
#     Dimension reduction type: normal
#
#     Model type:  ExtraTreesClassifier
#     *** normal mean normal data without any change
#
# CPU times: user 4.67 s, sys: 4.33 s, total: 9 s
# Wall time: 3.2 s

# %% [markdown]
# ---
# # test size 20%
# # with normize
# #  without Dimension reduction
# # all models
# ---

# %%
# %%time
######
model.find(X, y, 0.2, 1, 0, 1)
# Out:
#                 data  type normal
#                 dimension reduction  type normal
#                 i 0
#
#
#         model : KNeighborsClassifier
#
# normal data with normal dimension reduction - KNeighborsClassifier: training accuracy=86.67%, test accuracy=76.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  5  6]]
#         model : SVC
#
# normal data with normal dimension reduction - SVC: training accuracy=78.33%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : GaussianProcessClassifier
#
# normal data with normal dimension reduction - GaussianProcessClassifier: training accuracy=81.67%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  1 10]]
#         model : ExtraTreesClassifier
#
# normal data with normal dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=70.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  6  5]]
#         model : GaussianNB
#
# normal data with normal dimension reduction - GaussianNB: training accuracy=77.50%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : SVC_2
#
# normal data with normal dimension reduction - SVC_2: training accuracy=79.17%, test accuracy=93.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  0 11]]
#         model : DecisionTreeClassifier
#
# normal data with normal dimension reduction - DecisionTreeClassifier: training accuracy=94.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[9 1 0]
#  [0 4 5]
#  [0 5 6]]
#         model : RandomForestClassifier
#
# normal data with normal dimension reduction - RandomForestClassifier: training accuracy=94.17%, test accuracy=80.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  3  8]]
#         model : MLPClassifier
#
# normal data with normal dimension reduction - MLPClassifier: training accuracy=78.33%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  1 10]]
#         model : AdaBoostClassifier
#
# normal data with normal dimension reduction - AdaBoostClassifier: training accuracy=72.50%, test accuracy=60.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  3  6]
#  [ 0  6  5]]
#         model : QuadraticDiscriminantAnalysis
#
# normal data with normal dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=76.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#                 data  type MinMaxScaler
#                 dimension reduction  type normal
#                 i 1
#
#
#         model : KNeighborsClassifier
#
# MinMaxScaler data with normal dimension reduction - KNeighborsClassifier: training accuracy=85.00%, test accuracy=83.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  2  9]]
#         model : SVC
#
# MinMaxScaler data with normal dimension reduction - SVC: training accuracy=76.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : GaussianProcessClassifier
#
# MinMaxScaler data with normal dimension reduction - GaussianProcessClassifier: training accuracy=78.33%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : ExtraTreesClassifier
#
# MinMaxScaler data with normal dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=70.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  6  5]]
#         model : GaussianNB
#
# MinMaxScaler data with normal dimension reduction - GaussianNB: training accuracy=77.50%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : SVC_2
#
# MinMaxScaler data with normal dimension reduction - SVC_2: training accuracy=77.50%, test accuracy=83.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  3  8]]
#         model : DecisionTreeClassifier
#
# MinMaxScaler data with normal dimension reduction - DecisionTreeClassifier: training accuracy=94.17%, test accuracy=60.00%
# Confusion matrix, without normalization
# [[9 1 0]
#  [0 3 6]
#  [0 5 6]]
#         model : RandomForestClassifier
#
# MinMaxScaler data with normal dimension reduction - RandomForestClassifier: training accuracy=94.17%, test accuracy=80.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  3  8]]
#         model : MLPClassifier
#
# MinMaxScaler data with normal dimension reduction - MLPClassifier: training accuracy=80.83%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : AdaBoostClassifier
#
# MinMaxScaler data with normal dimension reduction - AdaBoostClassifier: training accuracy=74.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  4  5]
#  [ 0  6  5]]
#         model : QuadraticDiscriminantAnalysis
#
# MinMaxScaler data with normal dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=76.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#                 data  type Normalizer
#                 dimension reduction  type normal
#                 i 2
#
#
#         model : KNeighborsClassifier
#
# Normalizer data with normal dimension reduction - KNeighborsClassifier: training accuracy=82.50%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 1  5  3]
#  [ 0  7  4]]
#         model : SVC
#
# Normalizer data with normal dimension reduction - SVC: training accuracy=66.67%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  9  0]
#  [ 0 11  0]]
#         model : GaussianProcessClassifier
#
# Normalizer data with normal dimension reduction - GaussianProcessClassifier: training accuracy=69.17%, test accuracy=73.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  5  6]]
#         model : ExtraTreesClassifier
#
# Normalizer data with normal dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=60.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  4  5]
#  [ 0  7  4]]
#         model : GaussianNB
#
# Normalizer data with normal dimension reduction - GaussianNB: training accuracy=68.33%, test accuracy=73.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  5  6]]
#         model : SVC_2
#
# Normalizer data with normal dimension reduction - SVC_2: training accuracy=66.67%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  9  0]
#  [ 0 11  0]]
#         model : DecisionTreeClassifier
#
# Normalizer data with normal dimension reduction - DecisionTreeClassifier: training accuracy=94.17%, test accuracy=66.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  4  5]
#  [ 0  5  6]]
#         model : RandomForestClassifier
#
# Normalizer data with normal dimension reduction - RandomForestClassifier: training accuracy=94.17%, test accuracy=66.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  4  5]
#  [ 0  5  6]]
#         model : MLPClassifier
#
# Normalizer data with normal dimension reduction - MLPClassifier: training accuracy=71.67%, test accuracy=66.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  7  4]]
#         model : AdaBoostClassifier
#
# Normalizer data with normal dimension reduction - AdaBoostClassifier: training accuracy=69.17%, test accuracy=76.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  2  7]
#  [ 0  0 11]]
#         model : QuadraticDiscriminantAnalysis
#
# Normalizer data with normal dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=67.50%, test accuracy=73.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  4  5]
#  [ 0  3  8]]
#                 data  type scale
#                 dimension reduction  type normal
#                 i 3
#
#
#         model : KNeighborsClassifier
#
# scale data with normal dimension reduction - KNeighborsClassifier: training accuracy=84.17%, test accuracy=83.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  2  9]]
#         model : SVC
#
# scale data with normal dimension reduction - SVC: training accuracy=76.67%, test accuracy=83.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  3  8]]
#         model : GaussianProcessClassifier
#
# scale data with normal dimension reduction - GaussianProcessClassifier: training accuracy=77.50%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : ExtraTreesClassifier
#
# scale data with normal dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=70.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  6  5]]
#         model : GaussianNB
#
# scale data with normal dimension reduction - GaussianNB: training accuracy=77.50%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : SVC_2
#
# scale data with normal dimension reduction - SVC_2: training accuracy=80.00%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  1 10]]
#         model : DecisionTreeClassifier
#
# scale data with normal dimension reduction - DecisionTreeClassifier: training accuracy=94.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[9 1 0]
#  [0 4 5]
#  [0 5 6]]
#         model : RandomForestClassifier
#
# scale data with normal dimension reduction - RandomForestClassifier: training accuracy=94.17%, test accuracy=80.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  3  8]]
#         model : MLPClassifier
#
# scale data with normal dimension reduction - MLPClassifier: training accuracy=80.00%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : AdaBoostClassifier
#
# scale data with normal dimension reduction - AdaBoostClassifier: training accuracy=74.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  4  5]
#  [ 0  6  5]]
#         model : QuadraticDiscriminantAnalysis
#
# scale data with normal dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=76.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#                 data  type StandardScaler
#                 dimension reduction  type normal
#                 i 4
#
#
#         model : KNeighborsClassifier
#
# StandardScaler data with normal dimension reduction - KNeighborsClassifier: training accuracy=84.17%, test accuracy=83.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  2  9]]
#         model : SVC
#
# StandardScaler data with normal dimension reduction - SVC: training accuracy=76.67%, test accuracy=83.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  3  8]]
#         model : GaussianProcessClassifier
#
# StandardScaler data with normal dimension reduction - GaussianProcessClassifier: training accuracy=77.50%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : ExtraTreesClassifier
#
# StandardScaler data with normal dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=70.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  6  5]]
#         model : GaussianNB
#
# StandardScaler data with normal dimension reduction - GaussianNB: training accuracy=77.50%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : SVC_2
#
# StandardScaler data with normal dimension reduction - SVC_2: training accuracy=80.00%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  1 10]]
#         model : DecisionTreeClassifier
#
# StandardScaler data with normal dimension reduction - DecisionTreeClassifier: training accuracy=94.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[9 1 0]
#  [0 4 5]
#  [0 5 6]]
#         model : RandomForestClassifier
#
# StandardScaler data with normal dimension reduction - RandomForestClassifier: training accuracy=94.17%, test accuracy=80.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  4  7]]
#         model : MLPClassifier
#
# StandardScaler data with normal dimension reduction - MLPClassifier: training accuracy=78.33%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : AdaBoostClassifier
#
# StandardScaler data with normal dimension reduction - AdaBoostClassifier: training accuracy=74.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  4  5]
#  [ 0  6  5]]
#         model : QuadraticDiscriminantAnalysis
#
# StandardScaler data with normal dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=76.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#     ##############################
#     #### Find best parameter ####
#     ##############################
#
#     MAX SCORE: 0.9416666666666667
#
#     Preprocessing type: normal
#
#     Dimension reduction type: normal
#
#     Model type:  ExtraTreesClassifier
#     *** normal mean normal data without any change
#
# CPU times: user 28.5 s, sys: 25.2 s, total: 53.7 s
# Wall time: 20.4 s

# %% [markdown]
# ---
# # test size 20%
# # without normize
# # without Dimension reduction
# # all models
# ---

# %%
# %%time
######

model.find(X, y, 0.2, 0, 1,1)
# Out:
#                 data  type normal
#                 dimension reduction  type normal
#                 i 0
#
#
#         model : KNeighborsClassifier
#
# normal data with normal dimension reduction - KNeighborsClassifier: training accuracy=86.67%, test accuracy=76.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  5  6]]
#         model : SVC
#
# normal data with normal dimension reduction - SVC: training accuracy=78.33%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : GaussianProcessClassifier
#
# normal data with normal dimension reduction - GaussianProcessClassifier: training accuracy=81.67%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  1 10]]
#         model : ExtraTreesClassifier
#
# normal data with normal dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=70.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  6  5]]
#         model : GaussianNB
#
# normal data with normal dimension reduction - GaussianNB: training accuracy=77.50%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : SVC_2
#
# normal data with normal dimension reduction - SVC_2: training accuracy=79.17%, test accuracy=93.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  0 11]]
#         model : DecisionTreeClassifier
#
# normal data with normal dimension reduction - DecisionTreeClassifier: training accuracy=94.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[9 1 0]
#  [0 4 5]
#  [0 5 6]]
#         model : RandomForestClassifier
#
# normal data with normal dimension reduction - RandomForestClassifier: training accuracy=94.17%, test accuracy=80.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  3  8]]
#         model : MLPClassifier
#
# normal data with normal dimension reduction - MLPClassifier: training accuracy=79.17%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  1 10]]
#         model : AdaBoostClassifier
#
# normal data with normal dimension reduction - AdaBoostClassifier: training accuracy=74.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  4  5]
#  [ 0  6  5]]
#         model : QuadraticDiscriminantAnalysis
#
# normal data with normal dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=76.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#                 data  type normal
#                 dimension reduction  type TSNE
#                 i 1
#
#
#         model : KNeighborsClassifier
#
# normal data with TSNE dimension reduction - KNeighborsClassifier: training accuracy=86.67%, test accuracy=76.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  4  7]]
#         model : SVC
#
# normal data with TSNE dimension reduction - SVC: training accuracy=79.17%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : GaussianProcessClassifier
#
# normal data with TSNE dimension reduction - GaussianProcessClassifier: training accuracy=80.00%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : ExtraTreesClassifier
#
# normal data with TSNE dimension reduction - ExtraTreesClassifier: training accuracy=100.00%, test accuracy=76.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  4  7]]
#         model : GaussianNB
#
# normal data with TSNE dimension reduction - GaussianNB: training accuracy=80.00%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : SVC_2
#
# normal data with TSNE dimension reduction - SVC_2: training accuracy=91.67%, test accuracy=73.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  5  6]]
#         model : DecisionTreeClassifier
#
# normal data with TSNE dimension reduction - DecisionTreeClassifier: training accuracy=100.00%, test accuracy=73.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  6  5]]
#         model : RandomForestClassifier
#
# normal data with TSNE dimension reduction - RandomForestClassifier: training accuracy=100.00%, test accuracy=66.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  5  4]
#  [ 0  6  5]]
#         model : MLPClassifier
#
# normal data with TSNE dimension reduction - MLPClassifier: training accuracy=80.00%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : AdaBoostClassifier
#
# normal data with TSNE dimension reduction - AdaBoostClassifier: training accuracy=80.00%, test accuracy=80.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  3  6]
#  [ 0  0 11]]
#         model : QuadraticDiscriminantAnalysis
#
# normal data with TSNE dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=80.00%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#                 data  type normal
#                 dimension reduction  type ICA
#                 i 2
#
#
#         model : KNeighborsClassifier
#
# normal data with ICA dimension reduction - KNeighborsClassifier: training accuracy=83.33%, test accuracy=83.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  2  9]]
#         model : SVC
#
# normal data with ICA dimension reduction - SVC: training accuracy=76.67%, test accuracy=83.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  3  8]]
#         model : GaussianProcessClassifier
#
# normal data with ICA dimension reduction - GaussianProcessClassifier: training accuracy=78.33%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : ExtraTreesClassifier
#
# normal data with ICA dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=83.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  3  8]]
#         model : GaussianNB
#
# normal data with ICA dimension reduction - GaussianNB: training accuracy=79.17%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : SVC_2
#
# normal data with ICA dimension reduction - SVC_2: training accuracy=76.67%, test accuracy=80.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  4  7]]
#         model : DecisionTreeClassifier
#
# normal data with ICA dimension reduction - DecisionTreeClassifier: training accuracy=94.17%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  8  3]]
#         model : RandomForestClassifier
#
# normal data with ICA dimension reduction - RandomForestClassifier: training accuracy=94.17%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  2  9]]
#         model : MLPClassifier
#
# normal data with ICA dimension reduction - MLPClassifier: training accuracy=79.17%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : AdaBoostClassifier
#
# normal data with ICA dimension reduction - AdaBoostClassifier: training accuracy=68.33%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  9  0]
#  [ 0 11  0]]
#         model : QuadraticDiscriminantAnalysis
#
# normal data with ICA dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=76.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#                 data  type normal
#                 dimension reduction  type KernelPCA
#                 i 3
#
#
#         model : KNeighborsClassifier
#
# normal data with KernelPCA dimension reduction - KNeighborsClassifier: training accuracy=88.33%, test accuracy=83.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  3  8]]
#         model : SVC
#
# normal data with KernelPCA dimension reduction - SVC: training accuracy=78.33%, test accuracy=93.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  0 11]]
#         model : GaussianProcessClassifier
#
# normal data with KernelPCA dimension reduction - GaussianProcessClassifier: training accuracy=81.67%, test accuracy=80.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  5  4]
#  [ 0  2  9]]
#         model : ExtraTreesClassifier
#
# normal data with KernelPCA dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=70.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  6  5]]
#         model : GaussianNB
#
# normal data with KernelPCA dimension reduction - GaussianNB: training accuracy=79.17%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : SVC_2
#
# normal data with KernelPCA dimension reduction - SVC_2: training accuracy=81.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : DecisionTreeClassifier
#
# normal data with KernelPCA dimension reduction - DecisionTreeClassifier: training accuracy=94.17%, test accuracy=66.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  7  4]]
#         model : RandomForestClassifier
#
# normal data with KernelPCA dimension reduction - RandomForestClassifier: training accuracy=94.17%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  2  9]]
#         model : MLPClassifier
#
# normal data with KernelPCA dimension reduction - MLPClassifier: training accuracy=80.00%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : AdaBoostClassifier
#
# normal data with KernelPCA dimension reduction - AdaBoostClassifier: training accuracy=75.83%, test accuracy=70.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  9  2]]
#         model : QuadraticDiscriminantAnalysis
#
# normal data with KernelPCA dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=80.00%, test accuracy=76.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  4  7]]
#                 data  type normal
#                 dimension reduction  type PCA
#                 i 4
#
#
#         model : KNeighborsClassifier
#
# normal data with PCA dimension reduction - KNeighborsClassifier: training accuracy=85.83%, test accuracy=80.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  4  7]]
#         model : SVC
#
# normal data with PCA dimension reduction - SVC: training accuracy=81.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : GaussianProcessClassifier
#
# normal data with PCA dimension reduction - GaussianProcessClassifier: training accuracy=81.67%, test accuracy=86.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  1 10]]
#         model : ExtraTreesClassifier
#
# normal data with PCA dimension reduction - ExtraTreesClassifier: training accuracy=94.17%, test accuracy=70.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  6  5]]
#         model : GaussianNB
#
# normal data with PCA dimension reduction - GaussianNB: training accuracy=78.33%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : SVC_2
#
# normal data with PCA dimension reduction - SVC_2: training accuracy=79.17%, test accuracy=93.33%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  0 11]]
#         model : DecisionTreeClassifier
#
# normal data with PCA dimension reduction - DecisionTreeClassifier: training accuracy=94.17%, test accuracy=66.67%
# Confusion matrix, without normalization
# [[9 1 0]
#  [0 6 3]
#  [0 6 5]]
#         model : RandomForestClassifier
#
# normal data with PCA dimension reduction - RandomForestClassifier: training accuracy=94.17%, test accuracy=76.67%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  6  3]
#  [ 0  4  7]]
#         model : MLPClassifier
#
# normal data with PCA dimension reduction - MLPClassifier: training accuracy=81.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#         model : AdaBoostClassifier
#
# normal data with PCA dimension reduction - AdaBoostClassifier: training accuracy=72.50%, test accuracy=63.33%
# Confusion matrix, without normalization
# [[8 1 1]
#  [0 6 3]
#  [0 6 5]]
#         model : QuadraticDiscriminantAnalysis
#
# normal data with PCA dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=76.67%, test accuracy=90.00%
# Confusion matrix, without normalization
# [[10  0  0]
#  [ 0  7  2]
#  [ 0  1 10]]
#                 data  type normal
#                 dimension reduction  type UMAP
#                 i 5
# /home/amin/.local/lib/python3.6/site-packages/numba/np/ufunc/parallel.py:355: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
#         model : KNeighborsClassifier
#
# normal data with UMAP dimension reduction - KNeighborsClassifier: training accuracy=70.83%, test accuracy=40.00%
# Confusion matrix, without normalization
# [[4 2 4]
#  [4 4 1]
#  [6 1 4]]
#         model : SVC
#
# normal data with UMAP dimension reduction - SVC: training accuracy=41.67%, test accuracy=36.67%
# Confusion matrix, without normalization
# [[3 1 6]
#  [4 1 4]
#  [4 0 7]]
#         model : GaussianProcessClassifier
#
# normal data with UMAP dimension reduction - GaussianProcessClassifier: training accuracy=51.67%, test accuracy=33.33%
# Confusion matrix, without normalization
# [[3 6 1]
#  [2 6 1]
#  [6 4 1]]
#         model : ExtraTreesClassifier
#
# normal data with UMAP dimension reduction - ExtraTreesClassifier: training accuracy=100.00%, test accuracy=23.33%
# Confusion matrix, without normalization
# [[3 2 5]
#  [4 2 3]
#  [5 4 2]]
#         model : GaussianNB
#
# normal data with UMAP dimension reduction - GaussianNB: training accuracy=41.67%, test accuracy=33.33%
# Confusion matrix, without normalization
# [[3 2 5]
#  [4 1 4]
#  [4 1 6]]
#         model : SVC_2
#
# normal data with UMAP dimension reduction - SVC_2: training accuracy=65.00%, test accuracy=33.33%
# Confusion matrix, without normalization
# [[2 3 5]
#  [2 4 3]
#  [6 1 4]]
#         model : DecisionTreeClassifier
#
# normal data with UMAP dimension reduction - DecisionTreeClassifier: training accuracy=100.00%, test accuracy=30.00%
# Confusion matrix, without normalization
# [[2 3 5]
#  [3 4 2]
#  [4 4 3]]
#         model : RandomForestClassifier
#
# normal data with UMAP dimension reduction - RandomForestClassifier: training accuracy=100.00%, test accuracy=26.67%
# Confusion matrix, without normalization
# [[2 1 7]
#  [4 3 2]
#  [5 3 3]]
#         model : MLPClassifier
#
# normal data with UMAP dimension reduction - MLPClassifier: training accuracy=44.17%, test accuracy=36.67%
# Confusion matrix, without normalization
# [[3 2 5]
#  [4 1 4]
#  [4 0 7]]
#         model : AdaBoostClassifier
#
# normal data with UMAP dimension reduction - AdaBoostClassifier: training accuracy=72.50%, test accuracy=43.33%
# Confusion matrix, without normalization
# [[2 2 6]
#  [0 6 3]
#  [6 0 5]]
#         model : QuadraticDiscriminantAnalysis
#
# normal data with UMAP dimension reduction - QuadraticDiscriminantAnalysis: training accuracy=44.17%, test accuracy=33.33%
# Confusion matrix, without normalization
# [[3 1 6]
#  [4 2 3]
#  [4 2 5]]
#     ##############################
#     #### Find best parameter ####
#     ##############################
#
#     MAX SCORE: 1.0
#
#     Preprocessing type: normal
#
#     Dimension reduction type: TSNE
#
#     Model type:  ExtraTreesClassifier
#     *** normal mean normal data without any change
#
# CPU times: user 54.8 s, sys: 38.8 s, total: 1min 33s
# Wall time: 34.7 s
